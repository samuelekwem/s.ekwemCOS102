# %%
# A Python program to demonstrate defining a class

class Parrot:
    pass

# %%
obj = Parrot()
print(obj)

# %%
# Python program to demonstrate instantiating a class

class Dog:

    # Class attributes
    attr1 = "mammal"
    attr2 = "dog"

    # Instance method
    def fun(self):
        print("I'm a", self.attr1)
        print("I'm a", self.attr2)


# Object instantiation
Rodger = Dog()

# Accessing class attributes and method
print(Rodger.attr1)
Rodger.fun()
# Out:
# mammal
# I'm a mammal
# I'm a dog

# %%
# It is clearly seen that self and obj are referring to the same object

class Check:
    def __init__(self):
        print("Address of self =", id(self))


obj = Check()
print("Address of class object =", id(obj))
# Out:
# Address of self = 2961637616544
# Address of class object = 2961637616544

# %%
class Car:

    # Constructor
    def __init__(self, model, color):
        self.model = model
        self.color = color

    def show(self):
        print("Model is", self.model)
        print("Color is", self.color)


car1 = Car("Toyota", "Black")
car1.show()
# Out:
# Model is Toyota
# Color is Black

# %%
# Self is always required as the first argument

class Check:
    def __init__(self):
        print("This is Constructor")


object1 = Check()
print("Worked fine")
# Out:
# This is Constructor
# Worked fine

# %%
# Write Python3 code here

class ThisIsClass:
    def __init__(in_place_of_self):
        print("We have used another parameter name in place of self")


object1 = ThisIsClass()
# Out:
# We have used another parameter name in place of self

# %%
# A class with init method

class Person:

    # Constructor
    def __init__(self, name):
        self.name = name

    # Method
    def say_hi(self):
        print('Hello, my name is', self.name)


p = Person('Samuel')
p.say_hi()
# Out:
# Hello, my name is Samuel

# %%
class Person:

    # Constructor
    def __init__(self, name):
        self.name = name

    # Method
    def say_hi(self):
        print('Hello, my name is', self.name)


person1 = Person("John")
person1.say_hi()
# Out:
# Hello, my name is John

# %%
class Program:

    course = "COS 102 - Introduction to Problem Solving"

    # Default constructor
    def __init__(self):
        self.course = "COS 102 - Introduction to Problem Solving"

    def display(self):
        print(self.course)


obj = Program()
obj.display()
# Out:
# COS 102 - Introduction to Problem Solving

# %%
class Addition:
    first = 0
    second = 0
    answer = 0

    # Parameterized constructor
    def __init__(self, f, s):
        self.first = f
        self.second = s

    def display(self):
        print("First number =", self.first)
        print("Second number =", self.second)
        print("Addition =", self.answer)

    def calculate(self):
        self.answer = self.first + self.second


obj = Addition(1000, 2000)
obj.calculate()
obj.display()
# Out:
# First number = 1000
# Second number = 2000
# Addition = 3000

# %%
class Dog:

    # Class attribute
    attr1 = "mammal"

    # Instance attribute
    def __init__(self, name):
        self.name = name


# Object instantiation
Dog1 = Dog("Oscar")
Dog2 = Dog("Peaches")

print("Dog1 is a {}".format(Dog1.__class__.attr1))
print("Dog2 is also a {}".format(Dog2.__class__.attr1))

print("My name is {}".format(Dog1.name))
print("My name is {}".format(Dog2.name))
# Out:
# Dog1 is a mammal
# Dog2 is also a mammal
# My name is Oscar
# My name is Peaches

# %%
class SST:

    # Class attribute
    prog1 = "Computer Science"

    # Instance attribute
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("My name is {}".format(self.name))
        print("I study {}".format(self.__class__.prog1))


student1 = SST("Samuel")
student1.speak()
# Out:
# My name is Samuel
# I study Computer Science
