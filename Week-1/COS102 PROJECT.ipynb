# %%
# Simple Interest Program

P = float(input("Enter Principal: "))
R = float(input("Enter Rate (%): "))
T = float(input("Enter Time (years): "))

SI = (P * R * T) / 100

print("Simple Interest =", SI)
# Out:
# Enter Principal:  5000
# Enter Rate (%):  5
# Enter Time (years):  3
# Simple Interest = 750.0

# %%
# Compound Interest Program

P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
n = int(input("Number of times interest compounded per year: "))
t = float(input("Enter time (years): "))

A = P * (1 + R/(100*n)) ** (n*t)

print("Amount =", A)
# Out:
# Enter Principal:  6000
# Enter Rate:  2
# Number of times interest compounded per year:  4
# Enter time (years):  3
# Amount = 6370.066871186989

# %%
# Annuity Plan Program

PMT = float(input("Enter payment per period: "))
R = float(input("Enter annual interest rate (%): "))
n = int(input("Enter number of compounding periods per year: "))
t = float(input("Enter number of years: "))

r = R / 100

A = PMT * ((1 + r/n) ** (n*t) - 1) / (r/n)

print("Future Value of Annuity =", A)
# Out:
# Enter payment per period:  5500
# Enter annual interest rate (%):  4
# Enter number of compounding periods per year:  3
# Enter number of years:  5
# Future Value of Annuity = 90663.21824901135
