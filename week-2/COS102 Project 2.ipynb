# %%
BEGIN
  CREATE variable total_price = 0
  FOR each item in cart:
    SCAN item
    GET item_price
    total_price = total_price + item_price
  END FOR
  DISPLAY total_price
  INPUT payment_amount
  IF payment_amount >= total_price:
    Calculate change = payment_amount - total_price
    PRINT receipt
    OPEN cash drawer / process card
  ELSE:
    DISPLAY "Insufficient funds"
  END IF
END

# %%
name1 = input("Enter first name: ")
age1 = int(input(f"Enter {name1}'s age: "))

name2 = input("Enter second name: ")
age2 = int(input(f"Enter {name2}'s age: "))

# The Swap
temp_age = age1
age1 = age2
age2 = temp_age

print(f"After swapping: {name1} is {age1} and {name2} is {age2}")
# Out:
# Enter first name:  Samuel
# Enter Samuel's age:  18
# Enter second name:  Ekwem
# Enter Ekwem's age:  18
# After swapping: Samuel is 18 and Ekwem is 18
